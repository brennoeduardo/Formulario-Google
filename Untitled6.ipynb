# %% [markdown]
# <a href="https://colab.research.google.com/github/brennoeduardo/Formulario-Google/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
preço = float(input('Qual o preço do produto?'))
desconto = float(input('Qual o desconto do produto?'))
valorCalculado = preço - ( preço * desconto / 100)
print(round(valorCalculado, 2))
# Out:
# Qual o preço do produto?159.34
# Qual o desconto do produto?7.05
# 148.11
